# %%
 import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "drive/MyDrive/DSF Datasets/"

# %%
df = pd.read_csv(path + "Water levels Constanze.csv")
df
# Out:
#        Messstellennummer       Stationsname Gewaesser Parameter       Datum  \
# 0                    906  Konstanz Bodensee  Bodensee   W-Stand  1924-01-01
# 1                    906  Konstanz Bodensee  Bodensee   W-Stand  1924-01-02
# 2                    906  Konstanz Bodensee  Bodensee   W-Stand  1924-01-03
# 3                    906  Konstanz Bodensee  Bodensee   W-Stand  1924-01-04
# 4                    906  Konstanz Bodensee  Bodensee   W-Stand  1924-01-05
# ...                  ...                ...       ...       ...         ...
# 36831                906  Konstanz Bodensee  Bodensee   W-Stand  2024-11-02
# 36832                906  Konstanz Bodensee  Bodensee   W-Stand  2024-11-03
# 36833                906  Konstanz Bodensee  Bodensee   W-Stand  2024-11-04
# 36834                906  Konstanz Bodensee  Bodensee   W-Stand  2024-11-05
# 36835                906  Konstanz Bodensee  Bodensee   W-Stand  2024-11-06
#
#       Zeitbezug  Wert Einheit          Produkt
# ...

# %%
df = df[["Datum", "Wert"]]
df
# Out:
#             Datum  Wert
# 0      1924-01-01   326
# 1      1924-01-02   326
# 2      1924-01-03   324
# 3      1924-01-04   324
# 4      1924-01-05   324
# ...           ...   ...
# 36831  2024-11-02   354
# 36832  2024-11-03   351
# 36833  2024-11-04   348
# 36834  2024-11-05   346
# 36835  2024-11-06   344
#
# [36836 rows x 2 columns]

# %%
df.columns = ['DATE', 'WATER_LEVEL']
df.head()
# Out:
#          DATE  WATER_LEVEL
# 0  1924-01-01          326
# 1  1924-01-02          326
# 2  1924-01-03          324
# 3  1924-01-04          324
# 4  1924-01-05          324

# %%
df['DATE'] = pd.to_datetime(df['DATE'], format="%Y-%m-%d")
df.head()
# Out:
# <ipython-input-7-c0ecdc03884f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DATE'] = pd.to_datetime(df['DATE'], format="%Y-%m-%d")
#         DATE  WATER_LEVEL
# 0 1924-01-01          326
# 1 1924-01-02          326
# 2 1924-01-03          324
# 3 1924-01-04          324
# 4 1924-01-05          324

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36836 entries, 0 to 36835
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         36836 non-null  datetime64[ns]
#  1   WATER_LEVEL  36836 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 575.7 KB

# %%
# Weather datasets
# Checking for suspicious values

weather = pd.read_csv(path + "Weather Constanze_CLEAN/global_radiation.csv", na_values = -9999)
weather[weather["QUALITY"] == 1]
# Out:
#         SOUID      DATE  GLOBAL_RADIATION  QUALITY
# 27155  910929  20200507             376.0        1
# 27165  910929  20200517             366.0        1
# 27166  910929  20200518             396.0        1
# 27167  910929  20200519             393.0        1
# 27175  910929  20200527             383.0        1
# 27180  910929  20200601             393.0        1
# 27181  910929  20200602             414.0        1
# 27203  910929  20200624             416.0        1
# 27204  910929  20200625             417.0        1
# 27210  910929  20200701             400.0        1
# 27217  910929  20200708             415.0        1
# 27218  910929  20200709             384.0        1
# 27222  910929  20200713             407.0        1
# 27228  910929  20200719             395.0        1
# 27229  910929  20200720             385.0        1
# 27239  910929  20200730             373.0        1
# 27322  910929  20201021               4.0        1
# ...

# %%
# global radiation: very high or low values flagged as suspicious, but looks alright
# no suspicious values in other weather datasets

# %%
import os

for filename in os.listdir(path + "Weather Constanze_CLEAN"):
  weather_df = pd.read_csv(path + "Weather Constanze_CLEAN/" + filename, na_values = -9999)
  weather_df = weather_df.drop(columns=['SOUID', 'QUALITY'])
  weather_df['DATE'] = pd.to_datetime(weather_df['DATE'], format="%Y%m%d")
  df = pd.merge(df, weather_df, on='DATE', how='left')

# %%
df[25000:25020] # Looking at a part where all values exist
# Out:
#             DATE  WATER_LEVEL  HUMIDITY  MEAN_TEMP  PRECIPITATION  PRESSURE  \
# 25000 1992-06-12          400      82.0      145.0           19.0   10115.0
# 25001 1992-06-13          398      84.0      158.0           37.0   10153.0
# 25002 1992-06-14          396      71.0      182.0            0.0   10210.0
# 25003 1992-06-15          394      51.0      213.0            0.0   10179.0
# 25004 1992-06-16          393      52.0      221.0            0.0   10136.0
# 25005 1992-06-17          391      69.0      194.0            0.0   10158.0
# 25006 1992-06-18          391      59.0      190.0          159.0   10120.0
# 25007 1992-06-19          390      90.0      106.0           16.0   10131.0
# 25008 1992-06-20          390      73.0      158.0            0.0   10127.0
# 25009 1992-06-21          388      66.0      157.0            0.0   10165.0
# 25010 1992-06-22          386      73.0      198.0            0.0   10106.0
# ...

# %%
# Groundwater dataset
groundwater_df = pd.read_csv(path + "Groundwater Rielasingen.csv", sep = ';')
groundwater_df
# Out:
#                  Messstelle Grundwassernummer                Gemeinde  \
# 0     GWM 3198, Rielasingen        0101/372-4  Rielasingen-Worblingen
# 1     GWM 3198, Rielasingen        0101/372-4  Rielasingen-Worblingen
# 2     GWM 3198, Rielasingen        0101/372-4  Rielasingen-Worblingen
# 3     GWM 3198, Rielasingen        0101/372-4  Rielasingen-Worblingen
# 4     GWM 3198, Rielasingen        0101/372-4  Rielasingen-Worblingen
# ...                     ...               ...                     ...
# 3082  GWM 3198, Rielasingen        0101/372-4  Rielasingen-Worblingen
# 3083  GWM 3198, Rielasingen        0101/372-4  Rielasingen-Worblingen
# 3084  GWM 3198, Rielasingen        0101/372-4  Rielasingen-Worblingen
# 3085  GWM 3198, Rielasingen        0101/372-4  Rielasingen-Worblingen
# 3086  GWM 3198, Rielasingen        0101/372-4  Rielasingen-Worblingen
#
#        Nordwert  Ostwert        Komponente Messzeitpunkt Messwert    Einheit
# ...

# %%
groundwater_df = groundwater_df[["Messzeitpunkt", "Messwert"]]
groundwater_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3087 entries, 0 to 3086
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Messzeitpunkt  3087 non-null   object
#  1   Messwert       3087 non-null   object
# dtypes: object(2)
# memory usage: 48.4+ KB

# %%
groundwater_df['Messwert'] = groundwater_df['Messwert'].str.replace(',', '.').astype(float)
# Out:
# <ipython-input-15-98399395baa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   groundwater_df['Messwert'] = groundwater_df['Messwert'].str.replace(',', '.').astype(float)

# %%
groundwater_df.columns = ['DATE', 'GROUNDWATER_LEVEL']
groundwater_df['DATE'] = pd.to_datetime(groundwater_df['DATE'], format='%d.%m.%Y')
groundwater_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3087 entries, 0 to 3086
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   DATE               3087 non-null   datetime64[ns]
#  1   GROUNDWATER_LEVEL  3087 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 48.4 KB
# <ipython-input-16-75a2f8c5935b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   groundwater_df['DATE'] = pd.to_datetime(groundwater_df['DATE'], format='%d.%m.%Y')

# %%
groundwater_df.set_index('DATE', inplace=True)
groundwater_df = groundwater_df.resample('D').ffill() # Using forward fill to repeat the measurements daily until the next one
groundwater_df.reset_index(inplace=True)
groundwater_df
# Out:
#             DATE  GROUNDWATER_LEVEL
# 0     1962-11-05             413.27
# 1     1962-11-06             413.27
# 2     1962-11-07             413.27
# 3     1962-11-08             413.27
# 4     1962-11-09             413.27
# ...          ...                ...
# 22585 2024-09-05             413.63
# 22586 2024-09-06             413.63
# 22587 2024-09-07             413.63
# 22588 2024-09-08             413.63
# 22589 2024-09-09             413.65
#
# [22590 rows x 2 columns]

# %%
df = pd.merge(df, groundwater_df, on='DATE', how='left')

# %%
df[25000:25100] # Looking at a part where all values exist
# Out:
#             DATE  WATER_LEVEL  HUMIDITY  MEAN_TEMP  PRECIPITATION  PRESSURE  \
# 25000 1992-06-12          400      82.0      145.0           19.0   10115.0
# 25001 1992-06-13          398      84.0      158.0           37.0   10153.0
# 25002 1992-06-14          396      71.0      182.0            0.0   10210.0
# 25003 1992-06-15          394      51.0      213.0            0.0   10179.0
# 25004 1992-06-16          393      52.0      221.0            0.0   10136.0
# ...          ...          ...       ...        ...            ...       ...
# 25095 1992-09-15          316      71.0      163.0            0.0   10232.0
# 25096 1992-09-16          315      82.0      161.0            0.0   10235.0
# 25097 1992-09-17          313      76.0      168.0            0.0   10200.0
# 25098 1992-09-18          313      84.0      171.0            0.0   10193.0
# 25099 1992-09-19          312      85.0      168.0           15.0   10193.0
#
# ...

# %%
# Moon illumination dataset
moon_df = pd.read_csv(path + "Moon illumination.csv")
moon_df
# Out:
#               DATE  ILLUMINATION
# 0      1900-Jan-01       0.46612
# 1      1900-Jan-02       0.29235
# 2      1900-Jan-03       2.93634
# 3      1900-Jan-04       8.30151
# 4      1900-Jan-05      16.03276
# ...            ...           ...
# 45591  2024-Oct-28      17.33076
# 45592  2024-Oct-29      10.79418
# 45593  2024-Oct-30       5.67287
# 45594  2024-Oct-31       2.13026
# 45595  2024-Nov-01       0.30149
#
# [45596 rows x 2 columns]

# %%
moon_df.columns = ['DATE', 'MOON_ILLUMINATION']
moon_df['DATE'] = pd.to_datetime(moon_df['DATE'], format="%Y-%b-%d")
moon_df.head()
# Out:
#         DATE  MOON_ILLUMINATION
# 0 1900-01-01            0.46612
# 1 1900-01-02            0.29235
# 2 1900-01-03            2.93634
# 3 1900-01-04            8.30151
# 4 1900-01-05           16.03276

# %%
df = pd.merge(df, moon_df, on='DATE', how='left')

# %%
df['WATER_LEVEL'] = df['WATER_LEVEL'].astype(float)

# %%
df[30000:30010]
# Out:
#             DATE  WATER_LEVEL  HUMIDITY  MEAN_TEMP  PRECIPITATION  PRESSURE  \
# 30000 2006-02-19        242.0      68.0       62.0            0.0   10025.0
# 30001 2006-02-20        242.0      90.0       37.0            0.0   10058.0
# 30002 2006-02-21        242.0      87.0       32.0            0.0   10121.0
# 30003 2006-02-22        243.0      85.0       32.0            0.0   10188.0
# 30004 2006-02-23        244.0      88.0       17.0            0.0   10187.0
# 30005 2006-02-24        245.0      80.0       11.0            0.0   10125.0
# 30006 2006-02-25        245.0      84.0        3.0           32.0   10112.0
# 30007 2006-02-26        244.0      90.0      -10.0            9.0   10154.0
# 30008 2006-02-27        243.0      66.0      -22.0            0.0   10180.0
# 30009 2006-02-28        243.0      83.0      -24.0            2.0   10103.0
#
#        SNOW_DEPTH  SUNSHINE  WIND_SPEED  GLOBAL_RADIATION  GROUNDWATER_LEVEL  \
# ...

# %%
# Climate change dataset
climate_df = pd.read_csv(path + "Climate change.csv")
climate_df = climate_df[climate_df["Country"] == "Switzerland"]
climate_df.head()
# Out:
#      ObjectId      Country ISO2 ISO3  \
# 202       203  Switzerland   CH  CHE
#
#                                              Indicator            Unit  \
# 202  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                                 Source CTS Code  \
# 202  Food and Agriculture Organization of the Unite...     ECCS
#
#                        CTS Name  \
# 202  Surface Temperature Change
#
#                                    CTS Full Descriptor  ...   2014   2015  \
# 202  Environment, Climate Change, Climate and Weath...  ...  2.175  1.979
#
#       2016  2017   2018   2019   2020   2021   2022   2023
# 202  1.862  1.84  2.347  2.099  2.515  1.204  2.858  2.742
#
# [1 rows x 73 columns]

# %%
climate_df = climate_df.drop(columns = ["ObjectId","Country","ISO2","ISO3","Indicator","Unit","Source","CTS Code","CTS Name","CTS Full Descriptor"])
climate_df = pd.melt(climate_df, var_name="DATE", value_name="CLIMATE_CHANGE")
climate_df
# Out:
#     DATE  CLIMATE_CHANGE
# 0   1961           0.991
# 1   1962          -0.354
# 2   1963          -0.867
# 3   1964           0.138
# 4   1965          -0.788
# ..   ...             ...
# 58  2019           2.099
# 59  2020           2.515
# 60  2021           1.204
# 61  2022           2.858
# 62  2023           2.742
#
# [63 rows x 2 columns]

# %%
climate_df.info() # No missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23010 entries, 0 to 23009
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DATE            23010 non-null  datetime64[ns]
#  1   CLIMATE_CHANGE  23010 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 359.7 KB

# %%
climate_df = pd.concat([climate_df, pd.DataFrame({"DATE": [2024], "CLIMATE_CHANGE": [0.0]})], ignore_index=True) # Adding dummy for forward filling
climate_df['DATE'] = pd.to_datetime(climate_df['DATE'], format='%Y')

climate_df.set_index('DATE', inplace=True)
climate_df = climate_df.resample('D').ffill() # Using forward fill to repeat the measurements daily until the next one
climate_df.reset_index(inplace=True)

climate_df = climate_df[:-1] # Removing dummy
climate_df
# Out:
#             DATE  CLIMATE_CHANGE
# 0     1961-01-01           0.991
# 1     1961-01-02           0.991
# 2     1961-01-03           0.991
# 3     1961-01-04           0.991
# 4     1961-01-05           0.991
# ...          ...             ...
# 23005 2023-12-27           2.742
# 23006 2023-12-28           2.742
# 23007 2023-12-29           2.742
# 23008 2023-12-30           2.742
# 23009 2023-12-31           2.742
#
# [23010 rows x 2 columns]

# %%
df = pd.merge(df, climate_df, on='DATE', how='left')

# %%
df[30000:30010]
# Out:
#             DATE  WATER_LEVEL  HUMIDITY  MEAN_TEMP  PRECIPITATION  PRESSURE  \
# 30000 2006-02-19        242.0      68.0       62.0            0.0   10025.0
# 30001 2006-02-20        242.0      90.0       37.0            0.0   10058.0
# 30002 2006-02-21        242.0      87.0       32.0            0.0   10121.0
# 30003 2006-02-22        243.0      85.0       32.0            0.0   10188.0
# 30004 2006-02-23        244.0      88.0       17.0            0.0   10187.0
# 30005 2006-02-24        245.0      80.0       11.0            0.0   10125.0
# 30006 2006-02-25        245.0      84.0        3.0           32.0   10112.0
# 30007 2006-02-26        244.0      90.0      -10.0            9.0   10154.0
# 30008 2006-02-27        243.0      66.0      -22.0            0.0   10180.0
# 30009 2006-02-28        243.0      83.0      -24.0            2.0   10103.0
#
#        SNOW_DEPTH  SUNSHINE  WIND_SPEED  GLOBAL_RADIATION  GROUNDWATER_LEVEL  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36836 entries, 0 to 36835
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   DATE               36836 non-null  datetime64[ns]
#  1   WATER_LEVEL        36836 non-null  float64
#  2   HUMIDITY           28733 non-null  float64
#  3   MEAN_TEMP          28733 non-null  float64
#  4   PRECIPITATION      30559 non-null  float64
#  5   PRESSURE           18930 non-null  float64
#  6   SNOW_DEPTH         27777 non-null  float64
#  7   SUNSHINE           28137 non-null  float64
#  8   WIND_SPEED         23797 non-null  float64
#  9   GLOBAL_RADIATION   28082 non-null  float64
#  10  GROUNDWATER_LEVEL  22590 non-null  float64
#  11  MOON_ILLUMINATION  36831 non-null  float64
#  12  CLIMATE_CHANGE     23010 non-null  float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 3.7 MB

# %%
df.set_index("DATE", inplace = True)

# %%
df.to_csv('DSF Dataset CLEANED.csv')
